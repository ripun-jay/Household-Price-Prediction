# %%
# %%time


from sklearn.linear_model import LinearRegression
from sklearn.tree import DecisionTreeRegressor
from sklearn.ensemble import RandomForestRegressor


from sklearn.model_selection import train_test_split
from sklearn.model_selection import cross_val_score
from sklearn.model_selection import GridSearchCV

import pandas as pd
import numpy as np

from sklearn.pipeline import Pipeline

from preprocessing import preprocessing

from sklearn.metrics import mean_squared_error

# import data

housing = pd.read_csv("files/housing.csv")
housing.columns

# train test split

housing_train, housing_test = train_test_split(housing, test_size= 0.2, stratify= housing["ocean_proximity"], random_state= 42)

# target and feature dataset

y_train = housing_train["median_house_value"]
X_train = housing_train.drop("median_house_value", axis=1)

# looking for new complex/powerful model

# from sklearn.ensemble import RandomForestRegressor

rnd_forest = Pipeline([
    ("preprocessing", preprocessing),
    ("randomforest", RandomForestRegressor(random_state= 42))
],
# memory= 
)

# %%time
rnd_forest.fit(X_train, y_train)

# lin_reg -->  68000,   NA
# tree --> 0.0 ,  67000
# forest --> 17000,  47000
# Out:
# C:\Python\Lib\site-packages\sklearn\cluster\_kmeans.py:1412: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# C:\Python\Lib\site-packages\sklearn\preprocessing\_encoders.py:972: FutureWarning: `sparse` was renamed to `sparse_output` in version 1.2 and will be removed in 1.4. `sparse_output` is ignored unless you leave `sparse` to its default value.
#   warnings.warn(
# CPU times: total: 1min 5s
# Wall time: 1min 15s
# Pipeline(steps=[('preprocessing',
#                  ColumnTransformer(remainder=Pipeline(steps=[('impute',
#                                                               SimpleImputer(strategy='median')),
#                                                              ('scale',
#                                                               StandardScaler())]),
#                                    transformers=[('bedrooms',
#                                                   Pipeline(steps=[('simpleimputer',
#                                                                    SimpleImputer(strategy='median')),
#                                                                   ('ratio',
#                                                                    FunctionTransformer(feature_names_out=<function column_name at 0x000001E4766B1940>,
#                                                                                        func=<function rati...
#                                                   Pipeline(steps=[('impute',
#                                                                    SimpleImputer(strategy='median')),
#                                                                   ('similarity',
#                                                                    FunctionTransformer(feature_names_out=<function similarity_clms at 0x000001E4766B3740>,
#                                                                                        func=<function rbf_kernel at 0x000001E4735AB7E0>,
#                                                                                        kw_args={'Y': [[35]],
#                                                                                                 'gamma': 0.1})),
#                                                                   ('standardscaler',
#                                                                    StandardScaler())]),
#                                                   ['housing_median_age'])])),
#                 ('randomforest', RandomForestRegressor(random_state=42))])

# %% [markdown]
# ### grid Search -- fine for fewer combinatons, for higher combination it is computationally expensive

# %% [markdown]
# ## Randomized Search CV --  for higher parametr search space

# %% [raw]
# par --> 8
# spece --> 5
# 8*5 --> 40

# %%
from scipy.stats import randint

param_distribs = {
    "preprocessing__geo__n_clusters" : randint(low= 3, high= 50) ,   
    "randomforest__max_features" : randint(low=2, high = 20)
    }

# %%
randint(low= 3, high= 50)

# %%
from sklearn.model_selection import RandomizedSearchCV

rnd_search = RandomizedSearchCV(
    rnd_forest,
    param_distributions= param_distribs,
    n_iter= 10,
    cv = 3,
    scoring= "neg_root_mean_squared_error",
    random_state= 42,
    refit= True
)

# %%
# %%time
rnd_search.fit(X_train, y_train)
# Out:
# C:\Python\Lib\site-packages\sklearn\cluster\_kmeans.py:1412: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# C:\Python\Lib\site-packages\sklearn\preprocessing\_encoders.py:972: FutureWarning: `sparse` was renamed to `sparse_output` in version 1.2 and will be removed in 1.4. `sparse_output` is ignored unless you leave `sparse` to its default value.
#   warnings.warn(
# C:\Python\Lib\site-packages\sklearn\cluster\_kmeans.py:1412: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# C:\Python\Lib\site-packages\sklearn\preprocessing\_encoders.py:972: FutureWarning: `sparse` was renamed to `sparse_output` in version 1.2 and will be removed in 1.4. `sparse_output` is ignored unless you leave `sparse` to its default value.
#   warnings.warn(
# C:\Python\Lib\site-packages\sklearn\cluster\_kmeans.py:1412: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# C:\Python\Lib\site-packages\sklearn\preprocessing\_encoders.py:972: FutureWarning: `sparse` was renamed to `sparse_output` in version 1.2 and will be removed in 1.4. `sparse_output` is ignored unless you leave `sparse` to its default value.
#   warnings.warn(
# C:\Python\Lib\site-packages\sklearn\cluster\_kmeans.py:1412: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# C:\Python\Lib\site-packages\sklearn\preprocessing\_encoders.py:972: FutureWarning: `sparse` was renamed to `sparse_output` in version 1.2 and will be removed in 1.4. `sparse_output` is ignored unless you leave `sparse` to its default value.
#   warnings.warn(
# C:\Python\Lib\site-packages\sklearn\cluster\_kmeans.py:1412: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# C:\Python\Lib\site-packages\sklearn\preprocessing\_encoders.py:972: FutureWarning: `sparse` was renamed to `sparse_output` in version 1.2 and will be removed in 1.4. `sparse_output` is ignored unless you leave `sparse` to its default value.
#   warnings.warn(
# C:\Python\Lib\site-packages\sklearn\cluster\_kmeans.py:1412: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# C:\Python\Lib\site-packages\sklearn\preprocessing\_encoders.py:972: FutureWarning: `sparse` was renamed to `sparse_output` in version 1.2 and will be removed in 1.4. `sparse_output` is ignored unless you leave `sparse` to its default value.
#   warnings.warn(
# C:\Python\Lib\site-packages\sklearn\cluster\_kmeans.py:1412: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# C:\Python\Lib\site-packages\sklearn\preprocessing\_encoders.py:972: FutureWarning: `sparse` was renamed to `sparse_output` in version 1.2 and will be removed in 1.4. `sparse_output` is ignored unless you leave `sparse` to its default value.
#   warnings.warn(
# C:\Python\Lib\site-packages\sklearn\cluster\_kmeans.py:1412: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# C:\Python\Lib\site-packages\sklearn\preprocessing\_encoders.py:972: FutureWarning: `sparse` was renamed to `sparse_output` in version 1.2 and will be removed in 1.4. `sparse_output` is ignored unless you leave `sparse` to its default value.
#   warnings.warn(
# C:\Python\Lib\site-packages\sklearn\cluster\_kmeans.py:1412: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# C:\Python\Lib\site-packages\sklearn\preprocessing\_encoders.py:972: FutureWarning: `sparse` was renamed to `sparse_output` in version 1.2 and will be removed in 1.4. `sparse_output` is ignored unless you leave `sparse` to its default value.
#   warnings.warn(
# C:\Python\Lib\site-packages\sklearn\cluster\_kmeans.py:1412: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# C:\Python\Lib\site-packages\sklearn\preprocessing\_encoders.py:972: FutureWarning: `sparse` was renamed to `sparse_output` in version 1.2 and will be removed in 1.4. `sparse_output` is ignored unless you leave `sparse` to its default value.
#   warnings.warn(
# C:\Python\Lib\site-packages\sklearn\cluster\_kmeans.py:1412: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# C:\Python\Lib\site-packages\sklearn\preprocessing\_encoders.py:972: FutureWarning: `sparse` was renamed to `sparse_output` in version 1.2 and will be removed in 1.4. `sparse_output` is ignored unless you leave `sparse` to its default value.
#   warnings.warn(
# C:\Python\Lib\site-packages\sklearn\cluster\_kmeans.py:1412: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# C:\Python\Lib\site-packages\sklearn\preprocessing\_encoders.py:972: FutureWarning: `sparse` was renamed to `sparse_output` in version 1.2 and will be removed in 1.4. `sparse_output` is ignored unless you leave `sparse` to its default value.
#   warnings.warn(
# C:\Python\Lib\site-packages\sklearn\cluster\_kmeans.py:1412: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# C:\Python\Lib\site-packages\sklearn\preprocessing\_encoders.py:972: FutureWarning: `sparse` was renamed to `sparse_output` in version 1.2 and will be removed in 1.4. `sparse_output` is ignored unless you leave `sparse` to its default value.
#   warnings.warn(
# C:\Python\Lib\site-packages\sklearn\cluster\_kmeans.py:1412: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# C:\Python\Lib\site-packages\sklearn\preprocessing\_encoders.py:972: FutureWarning: `sparse` was renamed to `sparse_output` in version 1.2 and will be removed in 1.4. `sparse_output` is ignored unless you leave `sparse` to its default value.
#   warnings.warn(
# C:\Python\Lib\site-packages\sklearn\cluster\_kmeans.py:1412: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# C:\Python\Lib\site-packages\sklearn\preprocessing\_encoders.py:972: FutureWarning: `sparse` was renamed to `sparse_output` in version 1.2 and will be removed in 1.4. `sparse_output` is ignored unless you leave `sparse` to its default value.
#   warnings.warn(
# C:\Python\Lib\site-packages\sklearn\cluster\_kmeans.py:1412: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# C:\Python\Lib\site-packages\sklearn\preprocessing\_encoders.py:972: FutureWarning: `sparse` was renamed to `sparse_output` in version 1.2 and will be removed in 1.4. `sparse_output` is ignored unless you leave `sparse` to its default value.
#   warnings.warn(
# C:\Python\Lib\site-packages\sklearn\cluster\_kmeans.py:1412: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# C:\Python\Lib\site-packages\sklearn\preprocessing\_encoders.py:972: FutureWarning: `sparse` was renamed to `sparse_output` in version 1.2 and will be removed in 1.4. `sparse_output` is ignored unless you leave `sparse` to its default value.
#   warnings.warn(
# C:\Python\Lib\site-packages\sklearn\cluster\_kmeans.py:1412: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# C:\Python\Lib\site-packages\sklearn\preprocessing\_encoders.py:972: FutureWarning: `sparse` was renamed to `sparse_output` in version 1.2 and will be removed in 1.4. `sparse_output` is ignored unless you leave `sparse` to its default value.
#   warnings.warn(
# C:\Python\Lib\site-packages\sklearn\cluster\_kmeans.py:1412: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# C:\Python\Lib\site-packages\sklearn\preprocessing\_encoders.py:972: FutureWarning: `sparse` was renamed to `sparse_output` in version 1.2 and will be removed in 1.4. `sparse_output` is ignored unless you leave `sparse` to its default value.
#   warnings.warn(
# C:\Python\Lib\site-packages\sklearn\cluster\_kmeans.py:1412: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# C:\Python\Lib\site-packages\sklearn\preprocessing\_encoders.py:972: FutureWarning: `sparse` was renamed to `sparse_output` in version 1.2 and will be removed in 1.4. `sparse_output` is ignored unless you leave `sparse` to its default value.
#   warnings.warn(
# C:\Python\Lib\site-packages\sklearn\cluster\_kmeans.py:1412: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# C:\Python\Lib\site-packages\sklearn\preprocessing\_encoders.py:972: FutureWarning: `sparse` was renamed to `sparse_output` in version 1.2 and will be removed in 1.4. `sparse_output` is ignored unless you leave `sparse` to its default value.
#   warnings.warn(
# C:\Python\Lib\site-packages\sklearn\cluster\_kmeans.py:1412: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# C:\Python\Lib\site-packages\sklearn\preprocessing\_encoders.py:972: FutureWarning: `sparse` was renamed to `sparse_output` in version 1.2 and will be removed in 1.4. `sparse_output` is ignored unless you leave `sparse` to its default value.
#   warnings.warn(
# C:\Python\Lib\site-packages\sklearn\cluster\_kmeans.py:1412: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# C:\Python\Lib\site-packages\sklearn\preprocessing\_encoders.py:972: FutureWarning: `sparse` was renamed to `sparse_output` in version 1.2 and will be removed in 1.4. `sparse_output` is ignored unless you leave `sparse` to its default value.
#   warnings.warn(
# C:\Python\Lib\site-packages\sklearn\cluster\_kmeans.py:1412: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# C:\Python\Lib\site-packages\sklearn\preprocessing\_encoders.py:972: FutureWarning: `sparse` was renamed to `sparse_output` in version 1.2 and will be removed in 1.4. `sparse_output` is ignored unless you leave `sparse` to its default value.
#   warnings.warn(
# C:\Python\Lib\site-packages\sklearn\cluster\_kmeans.py:1412: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# C:\Python\Lib\site-packages\sklearn\preprocessing\_encoders.py:972: FutureWarning: `sparse` was renamed to `sparse_output` in version 1.2 and will be removed in 1.4. `sparse_output` is ignored unless you leave `sparse` to its default value.
#   warnings.warn(
# C:\Python\Lib\site-packages\sklearn\cluster\_kmeans.py:1412: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# C:\Python\Lib\site-packages\sklearn\preprocessing\_encoders.py:972: FutureWarning: `sparse` was renamed to `sparse_output` in version 1.2 and will be removed in 1.4. `sparse_output` is ignored unless you leave `sparse` to its default value.
#   warnings.warn(
# C:\Python\Lib\site-packages\sklearn\cluster\_kmeans.py:1412: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# C:\Python\Lib\site-packages\sklearn\preprocessing\_encoders.py:972: FutureWarning: `sparse` was renamed to `sparse_output` in version 1.2 and will be removed in 1.4. `sparse_output` is ignored unless you leave `sparse` to its default value.
#   warnings.warn(
# C:\Python\Lib\site-packages\sklearn\cluster\_kmeans.py:1412: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# C:\Python\Lib\site-packages\sklearn\preprocessing\_encoders.py:972: FutureWarning: `sparse` was renamed to `sparse_output` in version 1.2 and will be removed in 1.4. `sparse_output` is ignored unless you leave `sparse` to its default value.
#   warnings.warn(
# C:\Python\Lib\site-packages\sklearn\cluster\_kmeans.py:1412: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# C:\Python\Lib\site-packages\sklearn\preprocessing\_encoders.py:972: FutureWarning: `sparse` was renamed to `sparse_output` in version 1.2 and will be removed in 1.4. `sparse_output` is ignored unless you leave `sparse` to its default value.
#   warnings.warn(
# C:\Python\Lib\site-packages\sklearn\cluster\_kmeans.py:1412: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# C:\Python\Lib\site-packages\sklearn\preprocessing\_encoders.py:972: FutureWarning: `sparse` was renamed to `sparse_output` in version 1.2 and will be removed in 1.4. `sparse_output` is ignored unless you leave `sparse` to its default value.
#   warnings.warn(
# C:\Python\Lib\site-packages\sklearn\cluster\_kmeans.py:1412: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# C:\Python\Lib\site-packages\sklearn\preprocessing\_encoders.py:972: FutureWarning: `sparse` was renamed to `sparse_output` in version 1.2 and will be removed in 1.4. `sparse_output` is ignored unless you leave `sparse` to its default value.
#   warnings.warn(
# CPU times: total: 8min 45s
# Wall time: 9min 38s
# RandomizedSearchCV(cv=3,
#                    estimator=Pipeline(steps=[('preprocessing',
#                                               ColumnTransformer(remainder=Pipeline(steps=[('impute',
#                                                                                            SimpleImputer(strategy='median')),
#                                                                                           ('scale',
#                                                                                            StandardScaler())]),
#                                                                 transformers=[('bedrooms',
#                                                                                Pipeline(steps=[('simpleimputer',
#                                                                                                 SimpleImputer(strategy='median')),
#                                                                                                ('ratio',
#                                                                                                 FunctionTransformer(feature_names_out=<function column_name at 0x00...
#                                              ('randomforest',
#                                               RandomForestRegressor(random_state=42))]),
#                    param_distributions={'preprocessing__geo__n_clusters': <scipy.stats._distn_infrastructure.rv_discrete_frozen object at 0x000001E475E78E50>,
#                                         'randomforest__max_features': <scipy.stats._distn_infrastructure.rv_discrete_frozen object at 0x000001E476A5D150>},
#                    random_state=42, scoring='neg_root_mean_squared_error')

# %%
rnd_search.best_params_
# Out:
# {'preprocessing__geo__n_clusters': 45, 'randomforest__max_features': 9}

# %%
rnd_search.cv_results_
# Out:
# {'mean_fit_time': array([36.51776695, 21.15816204, 17.94288111, 26.16334502, 10.88876462,
#         10.04418429,  7.47594595, 28.78998764, 16.29181918,  5.13750879]),
#  'std_fit_time': array([0.0879856 , 0.03336598, 0.1233689 , 0.14960318, 0.03574447,
#         0.02049133, 0.04536164, 0.1515989 , 0.05885948, 0.71347334]),
#  'mean_score_time': array([0.13212633, 0.13326971, 0.1354332 , 0.13988868, 0.12970797,
#         0.14557759, 0.13837186, 0.13411283, 0.13486433, 0.13290707]),
#  'std_score_time': array([0.00327601, 0.01485794, 0.00379048, 0.00582676, 0.00306085,
#         0.00729426, 0.00640228, 0.00259057, 0.00278987, 0.00719646]),
#  'param_preprocessing__geo__n_clusters': masked_array(data=[41, 45, 23, 21, 13, 42, 24, 26, 32, 4],
#               mask=[False, False, False, False, False, False, False, False,
#                     False, False],
#         fill_value='?',
#              dtype=object),
#  'param_randomforest__max_features': masked_array(data=[16, 9, 8, 12, 5, 4, 3, 13, 7, 2],
#               mask=[False, False, False, False, False, False, False, False,
#                     False, False],
#         fill_value='?',
#              dtype=object),
#  'params': [{'preprocessing__geo__n_clusters': 41,
#    'randomforest__max_features': 16},
#   {'preprocessing__geo__n_clusters': 45, 'randomforest__max_features': 9},
#   {'preprocessing__geo__n_clusters': 23, 'randomforest__max_features': 8},
#   {'preprocessing__geo__n_clusters': 21, 'randomforest__max_features': 12},
#   {'preprocessing__geo__n_clusters': 13, 'randomforest__max_features': 5},
#   {'preprocessing__geo__n_clusters': 42, 'randomforest__max_features': 4},
#   {'preprocessing__geo__n_clusters': 24, 'randomforest__max_features': 3},
#   {'preprocessing__geo__n_clusters': 26, 'randomforest__max_features': 13},
#   {'preprocessing__geo__n_clusters': 32, 'randomforest__max_features': 7},
#   {'preprocessing__geo__n_clusters': 4, 'randomforest__max_features': 2}],
#  'split0_test_score': array([-43882.84041159, -42527.85029667, -43523.60127883, -44686.47368827,
#         -43966.190649  , -42903.642386  , -43458.09071339, -44137.72457351,
#         -43020.72356868, -49578.66098365]),
#  'split1_test_score': array([-42786.34972008, -41244.68576219, -42672.40914442, -43775.44234338,
#         -43409.01945058, -42081.78103541, -42481.47714927, -43363.2974048 ,
#         -41982.64557282, -49800.4285813 ]),
#  'split2_test_score': array([-44645.79681752, -43918.71137429, -44868.02869532, -45932.73400478,
#         -45552.30692328, -44829.92589901, -45025.88673299, -45516.18040596,
#         -44419.00314282, -51813.09037905]),
#  'mean_test_score': array([-43771.6623164 , -42563.74914438, -43688.01303952, -44798.21667881,
#         -44309.17234096, -43271.7831068 , -43655.15153188, -44339.06746142,
#         -43140.79076144, -50397.39331467]),
#  'std_test_score': array([ 763.17595336, 1091.96147337,  903.86566973,  884.24796675,
#          907.98224227, 1151.72934916, 1048.05526479,  890.36716136,
#          998.25569547, 1005.13476723]),
#  'rank_test_score': array([ 6,  1,  5,  9,  7,  3,  4,  8,  2, 10])}

# %%
pd.DataFrame(rnd_search.cv_results_)
# Out:
#    mean_fit_time  std_fit_time  mean_score_time  std_score_time  \
# 0      36.517767      0.087986         0.132126        0.003276
# 1      21.158162      0.033366         0.133270        0.014858
# 2      17.942881      0.123369         0.135433        0.003790
# 3      26.163345      0.149603         0.139889        0.005827
# 4      10.888765      0.035744         0.129708        0.003061
# 5      10.044184      0.020491         0.145578        0.007294
# 6       7.475946      0.045362         0.138372        0.006402
# 7      28.789988      0.151599         0.134113        0.002591
# 8      16.291819      0.058859         0.134864        0.002790
# 9       5.137509      0.713473         0.132907        0.007196
#
#   param_preprocessing__geo__n_clusters param_randomforest__max_features  \
# 0                                   41                               16
# 1                                   45                                9
# 2                                   23                                8
# 3                                   21                               12
# 4                                   13                                5
# 5                                   42                                4
# 6                                   24                                3
# 7                                   26                               13
# 8                                   32                                7
# 9                                    4                                2
#
#                                               params  split0_test_score  \
# 0  {'preprocessing__geo__n_clusters': 41, 'random...      -43882.840412
# 1  {'preprocessing__geo__n_clusters': 45, 'random...      -42527.850297
# 2  {'preprocessing__geo__n_clusters': 23, 'random...      -43523.601279
# 3  {'preprocessing__geo__n_clusters': 21, 'random...      -44686.473688
# 4  {'preprocessing__geo__n_clusters': 13, 'random...      -43966.190649
# 5  {'preprocessing__geo__n_clusters': 42, 'random...      -42903.642386
# 6  {'preprocessing__geo__n_clusters': 24, 'random...      -43458.090713
# 7  {'preprocessing__geo__n_clusters': 26, 'random...      -44137.724574
# 8  {'preprocessing__geo__n_clusters': 32, 'random...      -43020.723569
# 9  {'preprocessing__geo__n_clusters': 4, 'randomf...      -49578.660984
#
#    split1_test_score  split2_test_score  mean_test_score  std_test_score  \
# 0      -42786.349720      -44645.796818    -43771.662316      763.175953
# 1      -41244.685762      -43918.711374    -42563.749144     1091.961473
# 2      -42672.409144      -44868.028695    -43688.013040      903.865670
# 3      -43775.442343      -45932.734005    -44798.216679      884.247967
# 4      -43409.019451      -45552.306923    -44309.172341      907.982242
# 5      -42081.781035      -44829.925899    -43271.783107     1151.729349
# 6      -42481.477149      -45025.886733    -43655.151532     1048.055265
# 7      -43363.297405      -45516.180406    -44339.067461      890.367161
# 8      -41982.645573      -44419.003143    -43140.790761      998.255695
# 9      -49800.428581      -51813.090379    -50397.393315     1005.134767
#
#    rank_test_score
# 0                6
# 1                1
# 2                5
# 3                9
# 4                7
# 5                3
# 6                4
# 7                8
# 8                2
# 9               10

# %% [markdown]
# # Final Model To Launch

# %%
final_model = rnd_search.best_estimator_

# %%
# Real Word Scanrion

# %%
X_train.ocean_proximity.value_counts()
# Out:
# ocean_proximity
# <1H OCEAN     7309
# INLAND        5241
# NEAR OCEAN    2126
# NEAR BAY      1832
# ISLAND           4
# Name: count, dtype: int64

# %%
df_test1 = X_train[X_train.ocean_proximity == "NEAR BAY"]
df_test1
y_df_test1 = y_train[X_train.ocean_proximity == "NEAR BAY"]

# %%
pred = final_model.predict(df_test1)
pred
# Out:
# array([497319.96, 368835.05, 242621.  , ..., 244060.  , 379228.  ,
#        306291.01])

# %%
y_df_test1
# Out:
# 2382     500001.0
# 15542    348700.0
# 4452     245500.0
# 3423     169900.0
# 19954    294100.0
#            ...
# 2972     323500.0
# 11670    338000.0
# 8940     238600.0
# 2816     389200.0
# 11253    310900.0
# Name: median_house_value, Length: 1832, dtype: float64

# %%
mean_squared_error(y_df_test1, pred, squared=False)
# Out:
# 17732.722363782545

# %%
X_train
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 2931     -121.88     38.00                22.0        721.0           117.0
# 4175     -117.82     33.85                18.0       1810.0           305.0
# 12703    -118.31     34.09                34.0       2065.0           839.0
# 16281    -120.76     38.60                14.0       2925.0           625.0
# 12420    -118.09     33.92                36.0        847.0           185.0
# ...          ...       ...                 ...          ...             ...
# 3666     -118.21     34.13                52.0       2465.0           611.0
# 17452    -122.88     38.34                20.0       3404.0           628.0
# 3006     -118.03     33.90                36.0       1143.0           193.0
# 3297     -118.36     34.09                36.0       1390.0           458.0
# 19932    -118.11     33.79                36.0       1993.0           354.0
#
#        population  households  median_income ocean_proximity
# 2931        367.0       129.0         5.3098          INLAND
# 4175       1189.0       326.0         5.2227       <1H OCEAN
# 12703      2626.0       775.0         1.8214       <1H OCEAN
# 16281      1226.0       437.0         2.5865          INLAND
# 12420       713.0       194.0         4.8542       <1H OCEAN
# ...           ...         ...            ...             ...
# 3666       1433.0       570.0         3.2500       <1H OCEAN
# 17452      1641.0       585.0         5.0574       <1H OCEAN
# 3006        826.0       188.0         5.3184       <1H OCEAN
# 3297        874.0       468.0         2.5812       <1H OCEAN
# 19932       884.0       337.0         5.5870       <1H OCEAN
#
# [16512 rows x 9 columns]

# %%
# Evaluate Your Final Model/ML system on test set

# %%
X_test = housing_test.drop("median_house_value", axis=1)
y_test = housing_test.median_house_value

# %%
X_test
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 7050     -121.81     38.01                47.0       1942.0           430.0
# 18040    -116.05     33.33                17.0        290.0            94.0
# 19045    -119.76     36.71                29.0       1745.0           441.0
# 2724     -122.25     37.80                42.0       4120.0          1065.0
# 464      -121.98     38.34                18.0       3876.0           916.0
# ...          ...       ...                 ...          ...             ...
# 11702    -124.17     41.76                20.0       2673.0           538.0
# 20128    -122.06     36.98                15.0       3385.0           669.0
# 16143    -122.31     37.94                38.0       2172.0           403.0
# 9591     -122.47     37.69                30.0        837.0           213.0
# 18688    -121.79     37.38                22.0       3650.0           527.0
#
#        population  households  median_income ocean_proximity
# 7050       1074.0       393.0         2.2361          INLAND
# 18040       135.0        57.0         1.7292          INLAND
# 19045      1530.0       391.0         1.5611          INLAND
# 2724       1715.0      1015.0         2.9345        NEAR BAY
# 464        2386.0       867.0         2.5938          INLAND
# ...           ...         ...            ...             ...
# 11702      1282.0       514.0         2.4605      NEAR OCEAN
# 20128      1571.0       615.0         4.2254      NEAR OCEAN
# 16143       945.0       384.0         4.3958        NEAR BAY
# 9591        606.0       199.0         4.8750      NEAR OCEAN
# 18688      1637.0       520.0         5.3774       <1H OCEAN
#
# [4128 rows x 9 columns]

# %%
y_test
# Out:
# 7050     105100.0
# 18040     81300.0
# 19045     44400.0
# 2724     225000.0
# 464      129500.0
#            ...
# 11702    105900.0
# 20128    320900.0
# 16143    194200.0
# 9591     258800.0
# 18688    325600.0
# Name: median_house_value, Length: 4128, dtype: float64

# %%
y_pred_test = final_model.predict(X_test)
y_pred_test
# Out:
# array([113232.  ,  64942.  ,  51921.  , ..., 189774.  , 265435.  ,
#        303276.02])

# %%
# evaluate

# %%
final_rmse = mean_squared_error(y_true= y_test, y_pred= y_pred_test , squared= False)
final_rmse
# Out:
# 40728.68702174712

# %% [raw]
# lin_reg -->  68000,   NA
# tree --> 0.0 ,  67000
# forest --> 17000  47000  40000

# %% [markdown]
# # Aproved for launch

# %% [markdown]
# ## some system improvment approches
# 1. specific error analyse
# 2. add extra feature
# 3. remove uninformative atttribue
# 4. outlier, round, cap

# %%
# feature improtence:
 
fi = final_model["randomforest"].feature_importances_
fi
# Out:
# array([6.76320216e-02, 5.39686176e-02, 4.69953006e-02, 5.89021169e-03,
#        6.91094202e-03, 6.65295994e-03, 6.34116822e-03, 1.79898285e-01,
#        5.71207183e-03, 9.17630612e-03, 1.09555924e-02, 1.89907102e-02,
#        8.67658378e-03, 9.06207982e-03, 1.69379709e-02, 1.01244390e-02,
#        1.22062570e-02, 1.77967053e-02, 1.19258346e-02, 6.98753245e-03,
#        6.52568980e-03, 4.12324851e-03, 1.39062463e-02, 7.12379928e-03,
#        2.55412041e-02, 4.20001606e-03, 9.31392296e-03, 7.78753843e-03,
#        5.34988592e-03, 6.26047749e-03, 8.55927808e-03, 1.44928544e-02,
#        1.54996104e-02, 1.83488124e-02, 1.43640027e-02, 9.55352852e-03,
#        1.20735613e-02, 6.67291227e-03, 1.31795964e-02, 1.02413896e-02,
#        8.62381999e-03, 6.84301536e-03, 1.06615537e-02, 5.25009297e-03,
#        1.88474100e-02, 6.00266176e-03, 1.89985969e-02, 1.65321814e-02,
#        1.30597992e-02, 1.01133126e-02, 1.13106713e-02, 1.73320650e-02,
#        4.00355088e-02, 2.10220477e-03, 8.07879761e-02, 1.04619976e-05,
#        1.67322220e-04, 2.66750533e-03, 4.69467540e-03])

# %%
len(final_model["randomforest"].feature_importances_)
# Out:
# 59

# %%
rnd_search.best_params_
# Out:
# {'preprocessing__geo__n_clusters': 45, 'randomforest__max_features': 9}

# %%
sorted(zip(fi, final_model["preprocessing"].get_feature_names_out()), reverse = True)
# Out:
# [(0.1798982848817322, 'log__median_income'),
#  (0.08078797611790621, 'cat__ocean_proximity_INLAND'),
#  (0.06763202161064677, 'bedrooms__ratio'),
#  (0.053968617569761054, 'rooms_per_house__ratio'),
#  (0.04699530064167568, 'people_per_house__ratio'),
#  (0.04003550880690142, 'geo__similarity with 45 cluster'),
#  (0.02554120412165464, 'geo__similarity with 17 cluster'),
#  (0.01899859692781792, 'geo__similarity with 39 cluster'),
#  (0.018990710170044132, 'geo__similarity with 4 cluster'),
#  (0.01884741004215697, 'geo__similarity with 37 cluster'),
#  (0.018348812393772437, 'geo__similarity with 26 cluster'),
#  (0.01779670529416739, 'geo__similarity with 10 cluster'),
#  (0.017332065049168354, 'geo__similarity with 44 cluster'),
#  (0.016937970930815487, 'geo__similarity with 7 cluster'),
#  (0.01653218138832321, 'geo__similarity with 40 cluster'),
#  (0.015499610351593746, 'geo__similarity with 25 cluster'),
#  (0.014492854389366686, 'geo__similarity with 24 cluster'),
#  (0.014364002734117526, 'geo__similarity with 27 cluster'),
#  (0.013906246336802036, 'geo__similarity with 15 cluster'),
#  (0.013179596364184741, 'geo__similarity with 31 cluster'),
#  (0.013059799153014398, 'geo__similarity with 41 cluster'),
#  (0.012206257044507153, 'geo__similarity with 9 cluster'),
#  (0.012073561313159845, 'geo__similarity with 29 cluster'),
#  (0.011925834648830099, 'geo__similarity with 11 cluster'),
#  (0.011310671331203219, 'geo__similarity with 43 cluster'),
#  (0.01095559239725458, 'geo__similarity with 3 cluster'),
#  (0.010661553725620616, 'geo__similarity with 35 cluster'),
#  (0.010241389619597174, 'geo__similarity with 32 cluster'),
#  (0.010124439022481035, 'geo__similarity with 8 cluster'),
#  (0.010113312640892175, 'geo__similarity with 42 cluster'),
#  (0.00955352852479407, 'geo__similarity with 28 cluster'),
#  (0.00931392296384265, 'geo__similarity with 19 cluster'),
#  (0.009176306116273037, 'geo__similarity with 2 cluster'),
#  (0.009062079817278159, 'geo__similarity with 6 cluster'),
#  (0.008676583776082518, 'geo__similarity with 5 cluster'),
#  (0.008623819987483001, 'geo__similarity with 33 cluster'),
#  (0.008559278081520709, 'geo__similarity with 23 cluster'),
#  (0.00778753843079521, 'geo__similarity with 20 cluster'),
#  (0.0071237992844595385, 'geo__similarity with 16 cluster'),
#  (0.006987532448331863, 'geo__similarity with 12 cluster'),
#  (0.006910942023841006, 'log__total_rooms'),
#  (0.006843015358752648, 'geo__similarity with 34 cluster'),
#  (0.006672912271531541, 'geo__similarity with 30 cluster'),
#  (0.006652959936763852, 'log__population'),
#  (0.006525689799191945, 'geo__similarity with 13 cluster'),
#  (0.006341168218111199, 'log__households'),
#  (0.006260477491583672, 'geo__similarity with 22 cluster'),
#  (0.006002661757003282, 'geo__similarity with 38 cluster'),
#  (0.005890211687488975, 'log__total_bedrooms'),
#  (0.005712071834779143, 'geo__similarity with 1 cluster'),
#  (0.005349885916090763, 'geo__similarity with 21 cluster'),
#  (0.005250092967535423, 'geo__similarity with 36 cluster'),
#  (0.004694675399579712, 'simil__Similarity With Housing age: 35'),
#  (0.004200016060800136, 'geo__similarity with 18 cluster'),
#  (0.0041232485132948965, 'geo__similarity with 14 cluster'),
#  (0.002667505326233847, 'cat__ocean_proximity_NEAR OCEAN'),
#  (0.0021022047701477974, 'cat__ocean_proximity_<1H OCEAN'),
#  (0.00016732221967879268, 'cat__ocean_proximity_NEAR BAY'),
#  (1.0461997561914538e-05, 'cat__ocean_proximity_ISLAND')]

# %% [markdown]
# # launch, Monitor and Maintain our system

# %%
housing
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0        -122.23     37.88                41.0        880.0           129.0
# 1        -122.22     37.86                21.0       7099.0          1106.0
# 2        -122.24     37.85                52.0       1467.0           190.0
# 3        -122.25     37.85                52.0       1274.0           235.0
# 4        -122.25     37.85                52.0       1627.0           280.0
# ...          ...       ...                 ...          ...             ...
# 20635    -121.09     39.48                25.0       1665.0           374.0
# 20636    -121.21     39.49                18.0        697.0           150.0
# 20637    -121.22     39.43                17.0       2254.0           485.0
# 20638    -121.32     39.43                18.0       1860.0           409.0
# 20639    -121.24     39.37                16.0       2785.0           616.0
#
#        population  households  median_income  median_house_value  \
# 0           322.0       126.0         8.3252            452600.0
# 1          2401.0      1138.0         8.3014            358500.0
# 2           496.0       177.0         7.2574            352100.0
# 3           558.0       219.0         5.6431            341300.0
# 4           565.0       259.0         3.8462            342200.0
# ...           ...         ...            ...                 ...
# 20635       845.0       330.0         1.5603             78100.0
# 20636       356.0       114.0         2.5568             77100.0
# 20637      1007.0       433.0         1.7000             92300.0
# 20638       741.0       349.0         1.8672             84700.0
# 20639      1387.0       530.0         2.3886             89400.0
#
#       ocean_proximity
# 0            NEAR BAY
# 1            NEAR BAY
# 2            NEAR BAY
# 3            NEAR BAY
# 4            NEAR BAY
# ...               ...
# 20635          INLAND
# 20636          INLAND
# 20637          INLAND
# 20638          INLAND
# 20639          INLAND
#
# [20640 rows x 10 columns]

# %%
# deployment

# save the model

import joblib

# %%
joblib.dump(final_model,"HouseXprice.pkl")
# Out:
# ['HouseXprice.pkl']
