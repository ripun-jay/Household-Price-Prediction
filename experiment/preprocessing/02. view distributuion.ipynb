# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
housing = pd.read_csv("files/housing.csv")

# %%
housing.hist(bins= 60, figsize= (12,8))
# Out:
# array([[<Axes: title={'center': 'longitude'}>,
#         <Axes: title={'center': 'latitude'}>,
#         <Axes: title={'center': 'housing_median_age'}>],
#        [<Axes: title={'center': 'total_rooms'}>,
#         <Axes: title={'center': 'total_bedrooms'}>,
#         <Axes: title={'center': 'population'}>],
#        [<Axes: title={'center': 'households'}>,
#         <Axes: title={'center': 'median_income'}>,
#         <Axes: title={'center': 'median_house_value'}>]], dtype=object)

# %% [markdown]
# # Markdown:-
# 1. lognitude and latitude --> 2-bell-disrtib(not pure)
# 2. total_rooms, total_bedrooms, population, household, median_income, median_house_value -->  bell_distrib(not pure)
# 3. housing_median_age, housing_median_valve --> upper cap(maybe)
